# %%
# !pip install neurokit2 opensignalsreader
import neurokit2 as nk
import numpy as np
import matplotlib.pyplot as plt
from opensignalsreader import OpenSignalsReader

archivo = '/content/derivacion 3 hipoventilacion.txt'
ekg = OpenSignalsReader(archivo)
signal = ekg.signal(2)

fs = 1000
inicio = int(10*fs)
fin = int(30*fs)
ecg_segment = signal[inicio:fin]

signals, info = nk.ecg_process(ecg_segment, sampling_rate=fs)
nk.ecg_plot(signals, info)

plt.gcf().set_size_inches(16,10)
plt.subplots_adjust(hspace=0.5, wspace=0.3)
plt.show()
# Out:
# Requirement already satisfied: neurokit2 in /usr/local/lib/python3.13/dist-packages (0.2.13)
# Requirement already satisfied: opensignalsreader in /usr/local/lib/python3.13/dist-packages (0.2.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from neurokit2) (3.10.0)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from neurokit2) (2.1.3)
# Requirement already satisfied: pandas<3.0.0 in /usr/local/lib/python3.13/dist-packages (from neurokit2) (2.2.3)
# Requirement already satisfied: pywavelets>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from neurokit2) (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from neurokit2) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from neurokit2) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from neurokit2) (1.16.3)
# Requirement already satisfied: setuptools<82.0.0 in /usr/local/lib/python3.13/dist-packages (from neurokit2) (80.10.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5.0->neurokit2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5.0->neurokit2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5.0->neurokit2) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5.0->neurokit2) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5.0->neurokit2) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5.0->neurokit2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5.0->neurokit2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5.0->neurokit2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<3.0.0->neurokit2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<3.0.0->neurokit2) (2026.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.0.0->neurokit2) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.0.0->neurokit2) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->neurokit2) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->neurokit2) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->neurokit2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->neurokit2) (2026.7.22)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn>=1.0.0->neurokit2) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->neurokit2) (1.17.0)
